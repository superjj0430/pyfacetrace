# %% [markdown]
# ## 導入 FaceTrace.py

# %%
import FaceTrace as ft
#載入人臉資料庫
ft.LoadDB()
# Out:
# get Feature from:train\四葉草\0.jpg
# get Feature from:train\李國源\0.jpg
# get Feature from:train\滴妹\0.jpg
# get Feature from:train\阿滴\0.jpg

# %% [markdown]
# ## 1.使用影片檔當輸入來做影像辨識

# %%
ft.predictVedio('demo.mp4')

# %% [markdown]
# ## 2.使用Webcam 當輸入來做影像辨識

# %%
ft.predictCam()

# %% [markdown]
# ## 3.使用Webcam做人臉資料收集

# %%
#按下 p 鍵做拍照，以下例來說：拍好的照片會放在路徑 "train/李國源" 中
ft.getPicFromCam(tag="李國源")

# %% [markdown]
# ## 4.由圖檔擷取人臉特徵向量

# %%
img = ft.loadImg('train\\阿滴\\0.jpg')
ft.getFeatureVector(img)
# Out:
# array([ 1.13784394e-04,  4.94545698e-02, -3.74282300e-02, -1.92667376e-02,
#        -7.07855150e-02, -3.25858872e-03, -6.96214512e-02, -9.03918594e-02,
#         1.42818049e-01, -7.61800632e-02,  2.61411637e-01, -3.68957780e-02,
#        -2.20053047e-01, -5.32682985e-02, -1.17299482e-01,  1.56942099e-01,
#        -1.28859058e-01, -8.92523006e-02, -2.84361281e-02,  1.25775021e-03,
#         1.63192779e-01,  6.89781234e-02, -2.58009939e-04,  1.13977224e-01,
#        -5.26423380e-02, -2.68758535e-01, -9.85517129e-02, -8.68118703e-02,
#        -9.78937279e-03, -1.44658342e-01, -5.03183603e-02,  2.46542832e-03,
#        -1.80511639e-01, -3.93885225e-02,  3.97472456e-02,  4.25546393e-02,
#         3.98911349e-02, -7.78483525e-02,  1.88341439e-01,  4.76029702e-02,
#        -2.09598675e-01,  7.98782036e-02,  4.38056700e-02,  2.22945467e-01,
#         1.42376274e-01,  9.72495824e-02, -2.40197610e-02, -1.63029358e-01,
# ...
